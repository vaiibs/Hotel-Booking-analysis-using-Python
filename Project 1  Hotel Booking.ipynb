# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings as w
w.filterwarnings("ignore")
pd.set_option('display.max_columns',100)

# %%
df=pd.read_csv("hotel_bookings.csv")
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# # EDA and Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.reservation_status_date=pd.to_datetime(df.reservation_status_date,format='%d/%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.482918     106.863097           0.707476
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
df.describe(include='O')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
df.hotel.unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
df.groupby('hotel')['adr'].agg('sum')
# Out:
# hotel
# City Hotel      8353803.24
# Resort Hotel    3803814.36
# Name: adr, dtype: float64

# %%
df.hotel.value_counts()
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop(['agent','company'],axis=1,inplace=True)
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.adr.plot(kind='box')
# Out:
# <Axes: >

# %%
df1=df[df['adr']<5000]
df1.shape
# Out:
# (118897, 30)

# %%
df1.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483167     106.903570           0.707462
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
df1.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df1.adr.plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # Data Visualization

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.is_canceled.value_counts()
# Out:
# is_canceled
# 0    74745
# 1    44153
# Name: count, dtype: int64

# %%
df1.hotel.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='hotel'>

# %%
df1.is_canceled.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='is_canceled'>

# %%
plt.figure(figsize=(9,5))
sns.countplot(data=df1,x='hotel',hue='is_canceled')
plt.legend(['not canceled', 'canceled'])
plt.xlabel("Hotels")
plt.ylabel("No of Reservations")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 2
#       1 plt.figure(figsize=(9,5))
# ----> 2 sns.countplot(data=df1,x='hotel',hue='is_canceled')
#       3 plt.legend(['not canceled', 'canceled'])
#       4 plt.xlabel("Hotels")
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
df.reset_index(inplace = True)
resort=df[df['hotel']=='Resort Hotel']
resort.is_canceled.value_counts(normalize=True)

# %%
city=df[df['hotel']=='City Hotel']
city.is_canceled.value_counts(normalize=True)

# %%
city.columns

# %%
cityADR=city.groupby('reservation_status_date')['adr'].mean()
resortADR=resort.groupby('reservation_status_date')['adr'].mean()
cityADR

# %%
plt.figure(figsize=(22,10))
sns.lineplot(data=cityADR, label='City Hotel')
sns.lineplot(data=resortADR, label='Resort Hotel')

plt.legend(fontsize = 20)
plt.xlabel('Dates')
plt.show()

# %%
df1['month']=df['reservation_status_date'].dt.month
df1['monthN']=df['reservation_status_date'].dt.strftime('%B')

# %%
plt.figure(figsize=(16,8))
sns.countplot(df1,x='monthN',palette = 'bright',hue='is_canceled')
plt.xlabel("Months")
plt.ylabel("Count of Reservations")
plt.legend(['not canceled', 'canceled'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 2
#       1 plt.figure(figsize=(16,8))
# ----> 2 sns.countplot(df1,x='monthN',palette = 'bright',hue='is_canceled')
#       3 plt.xlabel("Months")
#       4 plt.ylabel("Count of Reservations")
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
cancelledDF=df1[df1['is_canceled']==1]
plt.figure(figsize=(16,8))
sns.barplot(data=cancelledDF.groupby("month")[['adr']].sum().reset_index(),x='month',y='adr')
# Out:
# <Axes: xlabel='month', ylabel='adr'>

# %%
cancelledDF=df1[df1['is_canceled']==0]
plt.figure(figsize=(16,8))
sns.barplot(data=cancelledDF.groupby("month")[['adr']].sum().reset_index(),x='month',y='adr')
# Out:
# <Axes: xlabel='month', ylabel='adr'>

# %%
data=cancelledDF.country.value_counts().head(10)
plt.figure(figsize=(15,8))
plt.pie(data,autopct='%.2f',labels=data.index)
plt.show()

# %%
df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56402
# Offline TA/TO    24160
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: count, dtype: int64

# %%
cancelledDF['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        35664
# Offline TA/TO    15882
# Direct           10528
# Groups            7709
# Corporate         4133
# Complementary      644
# Aviation           185
# Name: count, dtype: int64

# %%
df1.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'month', 'monthN'],
#       dtype='object')

# %%
cancelleddf=df1[df1['is_canceled']==1]
cancelledADRdf=cancelleddf.groupby('reservation_status_date')[['adr']].mean()
notcancelleddf=df1[df1['is_canceled']==0]
notcancelledADRdf=notcancelleddf.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize=(18,8))
sns.lineplot(cancelledADRdf,x='reservation_status_date',y='adr',label='cancelled')
sns.lineplot(notcancelledADRdf,x='reservation_status_date',y='adr',label='not cancelled')
plt.legend(fontsize = 20)
plt.show()

# %%
cancelleddf = cancelleddf[(cancelleddf['reservation_status_date']>'2016') 
                                    & (cancelleddf['reservation_status_date']<'2017-09')]
notcancelleddf = notcancelleddf[(notcancelleddf['reservation_status_date']>'2016')
                                            & (notcancelleddf['reservation_status_date']<'2017-09')]

# %%
cancelledADRdf=cancelleddf.groupby('reservation_status_date')[['adr']].mean()
notcancelledADRdf=notcancelleddf.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize=(18,8))
sns.lineplot(cancelledADRdf,x='reservation_status_date',y='adr',label='cancelled')
sns.lineplot(notcancelledADRdf,x='reservation_status_date',y='adr',label='not cancelled')
plt.legend(fontsize = 20)
plt.show()
